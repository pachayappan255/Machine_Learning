# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,root_mean_squared_error

# %%
df=pd.read_csv('house_price_random_forest_.csv')
df.head()
# Out:
#    Area_sqft  Bedrooms  Bathrooms  Age_years  Distance_km  Parking  Floor  \
# 0       1460         3          3         14         18.6        2      5
# 1       1894         3          2         19         15.9        1      4
# 2       1730         3          2         14         12.2        2      0
# 3       1695         4          3         30          1.1        2      8
# 4       2238         5          5          0         15.7        3      8
#
#    Price_lakhs
# 0        57.77
# 1        73.61
# 2        78.57
# 3        94.00
# 4       133.52

# %%
x=df.drop(columns='Price_lakhs')
y=df['Price_lakhs']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
sns.boxplot(x)
# Out:
# <Axes: >

# %%
num_cols=x.select_dtypes(include="number").columns

# %%
preprocessing=ColumnTransformer(
    transformers=[
        ('min_scale',MinMaxScaler(),num_cols)
    ]
)
preprocessing
# Out:
# ColumnTransformer(transformers=[('min_scale', MinMaxScaler(),
#                                  Index(['Area_sqft', 'Bedrooms', 'Bathrooms', 'Age_years', 'Distance_km',
#        'Parking', 'Floor'],
#       dtype='str'))])

# %%
main_pipeline=Pipeline(
    steps=[
        ('pre',preprocessing),
        ('model',DecisionTreeRegressor())
    ]
)
main_pipeline
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('min_scale', MinMaxScaler(),
#                                                   Index(['Area_sqft', 'Bedrooms', 'Bathrooms', 'Age_years', 'Distance_km',
#        'Parking', 'Floor'],
#       dtype='str'))])),
#                 ('model', DecisionTreeRegressor())])

# %%
main_pipeline.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('min_scale', MinMaxScaler(),
#                                                   Index(['Area_sqft', 'Bedrooms', 'Bathrooms', 'Age_years', 'Distance_km',
#        'Parking', 'Floor'],
#       dtype='str'))])),
#                 ('model', DecisionTreeRegressor())])

# %%
ytrain_pred=main_pipeline.predict(xtrain)
ytest_pred=main_pipeline.predict(xtest)

# %%
mean_squared_error(ytrain,ytrain_pred)
# Out:
# 0.0

# %%
mean_squared_error(ytest,ytest_pred)
# Out:
# 118.49508449999999

# %%
mean_absolute_error(ytest,ytest_pred)
# Out:
# 8.763349999999997

# %%
mean_absolute_error(ytrain,ytrain_pred)
# Out:
# 0.0

# %%
r2_score(ytrain,ytrain_pred)
# Out:
# 1.0

# %%
r2_score(ytest,ytest_pred)
# Out:
# 0.9320081650003386

# %%
root_mean_squared_error(ytrain,ytrain_pred)
# Out:
# 0.0

# %%
root_mean_squared_error(ytest,ytest_pred)
# Out:
# 10.88554474980467

# %%
ytest
# Out:
# 521     73.38
# 737     84.97
# 740    133.71
# 660    123.30
# 411     41.44
#         ...
# 408     46.23
# 332     83.95
# 208    104.97
# 613     40.67
# 78      44.11
# Name: Price_lakhs, Length: 200, dtype: float64

# %%
main_pipeline1=Pipeline(
    steps=[
        ('model1',RandomForestRegressor())
    ]
)
main_pipeline1
# Out:
# Pipeline(steps=[('model1', RandomForestRegressor())])

# %%
main_pipeline1.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('model1', RandomForestRegressor())])

# %%
ytrain_pred1=main_pipeline.predict(xtrain)
ytest_pred1=main_pipeline.predict(xtest)

# %%
mean_squared_error(ytrain,ytrain_pred1)
# Out:
# 0.0

# %%
mean_squared_error(ytest,ytest_pred1)
# Out:
# 118.49508449999999

# %%
r2_score(ytrain,ytrain_pred1)
# Out:
# 1.0

# %%
r2_score(ytest,ytest_pred1)
# Out:
# 0.9320081650003386
