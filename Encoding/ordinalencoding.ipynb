# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split

# %%
d={
    'cat_col1':['A','B','B','D','B','A','C','C','A','A'],
    'cat_col2':['S1','S2','S3','S3','S1','S3','S2','S2','S1','S3'],
    'lable':['class0','class1','class2','class3','class4','class5','class6','class7','class8','class9',]
}

# %%
df=pd.DataFrame(d)

# %%
x=df.drop(columns='lable')
y=df['lable']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
encoder=OrdinalEncoder()
encoder.fit_transform(xtrain)
# Out:
# array([[0., 2.],
#        [0., 0.],
#        [2., 1.],
#        [1., 2.],
#        [0., 2.],
#        [1., 0.],
#        [3., 2.],
#        [2., 1.]])

# %%
xtrain
# Out:
#   cat_col1 cat_col2
# 5        A       S3
# 0        A       S1
# 7        C       S2
# 2        B       S3
# 9        A       S3
# 4        B       S1
# 3        D       S3
# 6        C       S2

# %%
'''
encoder=OrdinalEncoder(categories=['cat_cal1'])
encoder.fit_transform(xtrain)

#ValueError: Shape mismatch: if categories is an array, it has to be of shape (n_features,).
'''
# Out:
# "\nencoder=OrdinalEncoder(categories=['cat_cal1'])\nencoder.fit_transform(xtrain)\n\n#ValueError: Shape mismatch: if categories is an array, it has to be of shape (n_features,).\n"

# %%
'''encoder=OrdinalEncoder(categories=['cat_col'])
encoder.fit_transform(xtrain['cat_col1'])

#ValueError: Expected a 2-dimensional container but got <class 'pandas.Series'> instead. Pass a DataFrame containing a single row (i.e. single sample) or a single column (i.e. single feature) instead.
'''
# Out:
# "encoder=OrdinalEncoder(categories=['cat_col'])\nencoder.fit_transform(xtrain['cat_col1'])\n\n#ValueError: Expected a 2-dimensional container but got <class 'pandas.Series'> instead. Pass a DataFrame containing a single row (i.e. single sample) or a single column (i.e. single feature) instead.\n"

# %%
'''
encoder=OrdinalEncoder(categories=[['B','A']])
encoder.fit_transform(xtrain[['cat_col1'])

ValueError: Found unknown categories ['C', 'D'] in column 0 during fit



'''
# Out:
# "\nencoder=OrdinalEncoder(categories=[['B','A']])\nencoder.fit_transform(xtrain['cat_col1'])\n\n#ValueError: Expected a 2-dimensional container but got <class 'pandas.Series'> instead. Pass a DataFrame containing a single row (i.e. single sample) or a single column (i.e. single feature) instead.\n\n"

# %%
encoder=OrdinalEncoder(categories=[['B','A','C','D'],['S1','S2','S3']])
encoder.fit_transform(xtrain)
# Out:
# array([[1., 2.],
#        [1., 0.],
#        [2., 1.],
#        [0., 2.],
#        [1., 2.],
#        [0., 0.],
#        [3., 2.],
#        [2., 1.]])
