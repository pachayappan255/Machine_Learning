# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error,root_mean_squared_error

# %%
df=pd.read_csv(r'C:\Users\ayyok\OneDrive\Desktop\PYspider\MachineLearning\Student_Performance1.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  str
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), str(1)
# memory usage: 493.2 KB

# %%
df['Extracurricular Activities']=df['Extracurricular Activities'].map({'Yes':1,'No':0})

# %%
df.corr(numeric_only=True)
# Out:
#                                   Hours Studied  Previous Scores  \
# Hours Studied                          1.000000        -0.012390
# Previous Scores                       -0.012390         1.000000
# Extracurricular Activities             0.003873         0.008369
# Sleep Hours                            0.001245         0.005944
# Sample Question Papers Practiced       0.017463         0.007888
# Performance Index                      0.373730         0.915189
#
#                                   Extracurricular Activities  Sleep Hours  \
# Hours Studied                                       0.003873     0.001245
# Previous Scores                                     0.008369     0.005944
# Extracurricular Activities                          1.000000    -0.023284
# Sleep Hours                                        -0.023284     1.000000
# Sample Question Papers Practiced                    0.013103     0.003990
# ...

# %%
x=df.drop(columns='Performance Index')# (OR)x=df[['Hours Studied','Previous Scores','Extracurricular Activities','Sleep Hours','Sample Question Papers Practiced']]
y=df['Performance Index']

# %%
print(x)
print(y)
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %% [markdown]
# Check data is linear or non-linear

# %%
df.corr(numeric_only=True)
# Out:
#                                   Hours Studied  Previous Scores  \
# Hours Studied                          1.000000        -0.012390
# Previous Scores                       -0.012390         1.000000
# Extracurricular Activities             0.003873         0.008369
# Sleep Hours                            0.001245         0.005944
# Sample Question Papers Practiced       0.017463         0.007888
# Performance Index                      0.373730         0.915189
#
#                                   Extracurricular Activities  Sleep Hours  \
# Hours Studied                                       0.003873     0.001245
# Previous Scores                                     0.008369     0.005944
# Extracurricular Activities                          1.000000    -0.023284
# Sleep Hours                                        -0.023284     1.000000
# Sample Question Papers Practiced                    0.013103     0.003990
# ...

# %%
df.cov(numeric_only=True)
# Out:
#                                   Hours Studied  Previous Scores  \
# Hours Studied                          6.704520        -0.556391
# Previous Scores                       -0.556391       300.784930
# Extracurricular Activities             0.005014         0.072575
# Sleep Hours                            0.005468         0.174829
# Sample Question Papers Practiced       0.129654         0.392262
# Performance Index                     18.592055       304.946801
#
#                                   Extracurricular Activities  Sleep Hours  \
# Hours Studied                                       0.005014     0.005468
# Previous Scores                                     0.072575     0.174829
# Extracurricular Activities                          0.249998    -0.019743
# Sleep Hours                                        -0.019743     2.875951
# Sample Question Papers Practiced                    0.018785     0.019403
# ...

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %% [markdown]
# # train-test-split

# %% [markdown]
# **Syntax**
#
# xtrain,xtest,ytrain,ytest=train_test_split(
#
#     x,
#
#     y,
#
#     train_size=0.8,
#
#     random_state=42
# )

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=42)#train_size=0.8 to split the data for train and test
#Explain random test?(Interviwe question)

# %%
xtrain
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 9254              5               49                           0            7
# 1561              2               48                           1            7
# 1670              2               81                           0            7
# 6087              2               46                           0            6
# 6669              8               47                           0            9
# ...             ...              ...                         ...          ...
# 5734              8               50                           1            6
# 5191              4               68                           0            9
# 5390              9               48                           0            7
# 860               1               47                           0            9
# 7270              2               46                           0            6
#
# ...

# %%
model=LinearRegression()#Model creation

# %%
model.fit(xtrain,ytrain)#model training   #(model learns the pattern from xtrain(input) and ytrain(output)
#pattern? mx+c(straight line))
# Out:
# LinearRegression()

# %%
ytrain
# Out:
# 9254    36.0
# 1561    25.0
# 1670    59.0
# 6087    22.0
# 6669    40.0
#         ...
# 5734    48.0
# 5191    51.0
# 5390    44.0
# 860     20.0
# 7270    24.0
# Name: Performance Index, Length: 8000, dtype: float64

# %%
model.intercept_   #Intercept value  #Attribute
# Out:
# np.float64(-33.921946215556126)

# %% [markdown]
# Intercept conclusion
#
# Base or initial value of 'performance index' is -33.921946215556126 when all features are equal to zero

# %%
model.coef_ # used to find slope value.
# Out:
# array([2.85248393, 1.0169882 , 0.60861668, 0.47694148, 0.19183144])

# %% [markdown]
# **Conclusion for slope**
#
# The rate of change of Performance Index is 2.85248393 with respect to Hours Studied by 1 unit.
#
#
# The rate of change of Performance Index is 1.0169882  with respect to Previous Score by 1 unit.
#
#
# The rate of change of Performance Index is 0.60861668 with respect to Extracurricular Activities by 1 unit.
#
#
# The rate of change of Performance Index is 0.47694148 with respect to Sleep Hours by 1 unit.
#
#
# The rate of change of Performance Index is 0.19183144 with respect to Sample Question Papers Practiced by 1 unit.

# %% [markdown]
# # Model evaluation

# %% [markdown]
# **Train data**

# %%
#error=actual output-predicted output

# %%
#ytrain(actual)
#ytrain_predicted(predicted_values)
''' 
syntax
model.predict(x)
ytrain_predicted=model.predict(xtrain)
ytest_predicted=model.predict(xtest)
'''
ytrain_predicted=model.predict(xtrain)

# %% [markdown]
# sntax for metrics
#
# metricname(actualoutput,predicted output)

# %%
r2_score(ytrain,ytrain_predicted)
# Out:
# 0.9886898790682355

# %% [markdown]
# **Conclusion**
#
# The model learns the pattern well(strong) bcuz previous scorre and target column corelated strongly

# %%
ytest_predicted=model.predict(xtest)

# %%
r2_score(ytest,ytest_predicted)
# Out:
# 0.9889832909573145

# %%
mean_absolute_error(ytest,ytest_predicted)
# Out:
# 1.6111213463123044

# %%
root_mean_squared_error(ytrain,ytrain_predicted)
# Out:
# 2.0419931071198567
