# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report

# %%
df=pd.read_csv('loan_data.csv')
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
x=df.drop(columns='loan_status')
y=df['loan_status']

# %%
num_cols=x.select_dtypes(include='number').columns
x=x[num_cols]

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
grid_search=GridSearchCV(
    estimator=DecisionTreeClassifier(random_state=42),
    param_grid={
        'criterion':['gini','entropy'],
        'splitter':['best','random'],
        'max_depth':[None,5,10,20],
        'min_samples_split':[2,3,5,7],
        'min_samples_leaf':[1,3,5,7],
        'max_features':['auto','sqrt','log2'] 
    },
    cv=5,
    verbose=0
)
grid_search.fit(xtrain,ytrain)
# Out:
# c:\Users\ayyok\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:489: FitFailedWarning:
# 1280 fits failed out of a total of 3840.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1280 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\ayyok\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 851, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\ayyok\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1393, in wrapper
#     estimator._validate_params()
# ...

# %%
grid_search.best_params_  #to get best parameter
# Out:
# {'criterion': 'entropy',
#  'max_depth': 10,
#  'max_features': 'log2',
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'splitter': 'best'}

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, max_features='log2',
#                        min_samples_leaf=3, random_state=42)

# %%
model=grid_search.best_estimator_
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, max_features='log2',
#                        min_samples_leaf=3, random_state=42)

# %%
ytrain_pred=model.predict(xtrain)
ytest_pred=model.predict(xtest)

# %%
print(classification_report(ytrain,ytrain_pred))
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92     28010
#            1       0.75      0.65      0.70      7990
#
#     accuracy                           0.87     36000
#    macro avg       0.83      0.79      0.81     36000
# weighted avg       0.87      0.87      0.87     36000
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91      6990
#            1       0.69      0.60      0.64      2010
#
#     accuracy                           0.85      9000
#    macro avg       0.79      0.76      0.77      9000
# weighted avg       0.85      0.85      0.85      9000

# %%
result=pd.DataFrame(grid_search.cv_results_)
result
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.004001      0.000910         0.000000        0.000000
# 1         0.002401      0.001021         0.000000        0.000000
# 2         0.002000      0.000633         0.000000        0.000000
# 3         0.002008      0.000632         0.000000        0.000000
# 4         0.001802      0.000749         0.000000        0.000000
# ..             ...           ...              ...             ...
# 763       0.018395      0.001356         0.003804        0.000401
# 764       0.077594      0.000972         0.004014        0.000023
# 765       0.018189      0.000734         0.003182        0.000413
# 766       0.075648      0.000921         0.003586        0.000464
# 767       0.018742      0.001108         0.003214        0.000346
#
#     param_criterion param_max_depth param_max_features  \
# 0              gini            None               auto
# 1              gini            None               auto
# ...

# %%
result.sort_values(by='rank_test_score')
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 648       0.067234      0.007017         0.003580        0.000817
# 652       0.056567      0.002311         0.002941        0.000196
# 650       0.060622      0.004081         0.003629        0.000484
# 664       0.055996      0.001660         0.003586        0.000477
# 670       0.062084      0.007532         0.003597        0.000796
# ..             ...           ...              ...             ...
# 19        0.004202      0.001164         0.000000        0.000000
# 18        0.004599      0.001856         0.000000        0.000000
# 17        0.001995      0.000628         0.000000        0.000000
# 16        0.002347      0.000598         0.000000        0.000000
# 15        0.002179      0.000958         0.000000        0.000000
#
#     param_criterion param_max_depth param_max_features  \
# 648         entropy              10               log2
# 652         entropy              10               log2
# ...

# %%
model=DecisionTreeClassifier(
criterion= 'entropy',
 max_depth= 10,
 max_features= 'log2',
 min_samples_leaf= 3,
 min_samples_split= 2,
 splitter= 'best',
 random_state=42)

# %%
model.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, max_features='log2',
#                        min_samples_leaf=3, random_state=42)

# %%
grid_search=GridSearchCV(
    estimator=DecisionTreeClassifier(random_state=42),
    param_grid={
        'criterion':['gini','entropy'],
        'splitter':['best','random'],
        'max_depth':[None,5,10,20],
        'min_samples_split':[2,3,5,7],
        'min_samples_leaf':[1,3,5,7],
        'max_features':['sqrt','log2'] 
    },
    cv=3,
    verbose=1,
    error_score='raise', #to find which para value is makes the nan values
    n_jobs=1 #if u want to use all the cpu cores pass -1 as a parameter value and runs parallely
)
grid_search.fit(xtrain,ytrain)
# Out:
# Fitting 3 folds for each of 512 candidates, totalling 1536 fits

# %%
model1=grid_search.best_estimator_
model1.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(max_depth=10, max_features='log2', min_samples_split=5,
#                        random_state=42)

# %%
result1=pd.DataFrame(grid_search.cv_results_)
result1.sort_values(by='rank_test_score')
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 164       0.040718      0.001853         0.003998    7.370010e-07
# 166       0.040012      0.000862         0.003693    4.922159e-04
# 162       0.039786      0.001684         0.003629    5.278569e-04
# 114       0.023004      0.000005         0.003348    4.583457e-04
# 118       0.022317      0.000445         0.003012    2.284869e-05
# ..             ...           ...              ...             ...
# 333       0.006996      0.000009         0.003003    6.633961e-06
# 75        0.007696      0.000930         0.003007    9.282974e-05
# 77        0.006997      0.000820         0.003035    7.287892e-04
# 73        0.007203      0.001130         0.003826    2.358169e-04
# 257       0.022352      0.000496         0.004966    1.085927e-04
#
#     param_criterion param_max_depth param_max_features  \
# 164            gini              10               log2
# 166            gini              10               log2
# ...

# %%
ytrain_pred=model1.predict(xtrain)
ytest_pred=model1.predict(xtest)

# %%
print(classification_report(ytrain,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92     28010
#            1       0.77      0.64      0.70      7990
#
#     accuracy                           0.88     36000
#    macro avg       0.84      0.79      0.81     36000
# weighted avg       0.87      0.88      0.87     36000

# %%
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      6990
#            1       0.70      0.59      0.64      2010
#
#     accuracy                           0.85      9000
#    macro avg       0.79      0.76      0.77      9000
# weighted avg       0.84      0.85      0.85      9000

# %%
grid_search=GridSearchCV(
    estimator=DecisionTreeClassifier(random_state=42),
    param_grid={
        'criterion':['gini','entropy'],
        'splitter':['best','random'],
        'max_depth':[None,5,10,20],
        'min_samples_split':[2,3,5,7],
        'min_samples_leaf':[1,3,5,7],
        'max_features':['auto','sqrt','log2'] 
    },
    cv=10,
    verbose=1
)
grid_search.fit(xtrain,ytrain)
# Out:
# Fitting 10 folds for each of 768 candidates, totalling 7680 fits
# c:\Users\ayyok\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:489: FitFailedWarning:
# 2560 fits failed out of a total of 7680.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 2560 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\ayyok\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 851, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\ayyok\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1393, in wrapper
# ...

# %%
model2=grid_search.best_estimator_
model2.fit(xtrain,ytrain)

# %%
ytrain_pred=model2.predict(xtrain)
ytest_pred=model2.predict(xtest)

# %%
print(classification_report(ytrain,ytrain_pred))
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.95      0.92     28010
#            1       0.77      0.64      0.70      7990
#
#     accuracy                           0.88     36000
#    macro avg       0.84      0.79      0.81     36000
# weighted avg       0.87      0.88      0.87     36000
#
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      6990
#            1       0.70      0.59      0.64      2010
#
#     accuracy                           0.85      9000
#    macro avg       0.79      0.76      0.77      9000
# weighted avg       0.84      0.85      0.85      9000

# %%
import os

# %%
print(os.cpu_count()) #12 cpu core #n_jobs=1 => 1 cpu core #n_jobs=2 =>2 cpu core #n_jobs=-1 => all cpu core
# Out:
# 12
